# %% [markdown]
# <a href="https://colab.research.google.com/github/roscoekerby/artificial-intelligence/blob/main/simple_cow_id_roboflow_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q roboflow
from roboflow import Roboflow
rf = Roboflow(model_format="folder", notebook="roboflow-resnet")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=folder&ref=roboflow-resnet

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="7Eb0syt8VDp2Ym16FI4s")
project = rf.workspace().project("cow-identification")
dataset = project.version(1).download("folder")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Cow-Identification-1 in folder:: 100%|██████████| 6693/6693 [00:08<00:00, 786.10it/s]

# %%
import torch
import torchvision.models as models
import os

model = project.version("1").model

for query_file_name in os.listdir("/content/Cow-Identification-1/query/"):
    if query_file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
      model.predict("/content/Cow-Identification-1/query/" + query_file_name).save("/content/Cow-Identification-1/predictions/" + query_file_name + "_prediction.jpg" )
      json = model.predict("/content/Cow-Identification-1/query/" + query_file_name).json()
      print(query_file_name)
      print(json)
# Out:
# cattle_4614_DSCF0846_jpg.rf.451ce45d75c0ae0eef37e977f339940d.jpg
# ...
